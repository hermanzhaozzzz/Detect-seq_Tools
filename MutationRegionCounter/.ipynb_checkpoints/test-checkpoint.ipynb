# %%
import pysam
import pandas as pd
from DetectSeqLib_V2.CheckAndLoadFiles import load_reference_fasta_as_dict
from DetectSeqLib_V2.RegionStatsTest import get_align_mismatch_pairs
from DetectSeqLib_V2.RegionStatsTest import get_No_MD_align_mismatch_pairs

# %%
ref_dict = load_reference_fasta_as_dict(ref_fasta_path="/Users/zhaohuanan/Nutstore/Coding/github/snakepipes_bioinformatics_hermanzhaozzzz/genome_fa/genome_ucsc_hg38.fa")
# Out:
# INFO  @ 2020-12-01 09:40:08: Starting to load the reference genome...
# DEBUG @ 2020-12-01 09:40:09: Loading genome...	chr1
# DEBUG @ 2020-12-01 09:40:11: Loading genome...	chr2
# DEBUG @ 2020-12-01 09:40:13: Loading genome...	chr3
# DEBUG @ 2020-12-01 09:40:15: Loading genome...	chr4
# DEBUG @ 2020-12-01 09:40:16: Loading genome...	chr5
# DEBUG @ 2020-12-01 09:40:18: Loading genome...	chr6
# DEBUG @ 2020-12-01 09:40:19: Loading genome...	chr7
# DEBUG @ 2020-12-01 09:40:21: Loading genome...	chr8
# DEBUG @ 2020-12-01 09:40:23: Loading genome...	chr9
# DEBUG @ 2020-12-01 09:40:24: Loading genome...	chr10
# DEBUG @ 2020-12-01 09:40:25: Loading genome...	chr11
# DEBUG @ 2020-12-01 09:40:27: Loading genome...	chr12
# DEBUG @ 2020-12-01 09:40:28: Loading genome...	chr13
# DEBUG @ 2020-12-01 09:40:28: Loading genome...	chr14
# DEBUG @ 2020-12-01 09:40:29: Loading genome...	chr15
# DEBUG @ 2020-12-01 09:40:30: Loading genome...	chr16
# DEBUG @ 2020-12-01 09:40:31: Loading genome...	chr17
# DEBUG @ 2020-12-01 09:40:31: Loading genome...	chr18
# DEBUG @ 2020-12-01 09:40:32: Loading genome...	chr19
# DEBUG @ 2020-12-01 09:40:32: Loading genome...	chr20
# DEBUG @ 2020-12-01 09:40:33: Loading genome...	chr21
# DEBUG @ 2020-12-01 09:40:33: Loading genome...	chr22
# DEBUG @ 2020-12-01 09:40:34: Loading genome...	chrX
# DEBUG @ 2020-12-01 09:40:35: Loading genome...	chrY
# DEBUG @ 2020-12-01 09:40:35: Loading genome...	chrM
# INFO  @ 2020-12-01 09:40:35: Loading genome done!

# %%
bam_file = pysam.AlignmentFile("./bam/293T-bat_VEGFA-All-PD_rep1_hg38.MAPQ20.bam", "rb")
# this bed file should have the name column [col4]
bed_file = './bed/GSE151265_293T-VEGFA-Detect-seq_pRBS.bed'
num_extend = 100
has_bed_header = True
ls_mut_direction = ['CT','GA']





with open(bed_file, "r") as f:
    ls_bed_info = [i.strip().split('\t') for i in f.readlines()]

if has_bed_header:
    ls_bed_info = ls_bed_info[1:]
# ls_bed_info[:3]
# Out:
# [['chr6', '43770819', '43770841', 'VEGFA-Site2-on-target'],
#  ['chr1', '93448683', '93448705', 'VEGFA-Site2-pRBS-1'],
#  ['chr15', '32993900', '32993922', 'VEGFA-Site2-pRBS-2']]

# %%
ls_table = []
for ls_bed_line in ls_bed_info:
#     print("*"*100)
#     print(ls_bed_line)
    chr_ = ls_bed_line[0]
    start =int(ls_bed_line[1]) - num_extend
    end = int(ls_bed_line[2]) + num_extend
    region_index = ls_bed_line[3].strip()
    
    
    for index, align in enumerate(bam_file.fetch(contig=chr_, start=start, end=end)):
#         print(index, '\n', align, '\n', align.get_aligned_pairs())
        MD_tag_state = align.has_tag("MD")

        if MD_tag_state:
            mis_align_pair_list = get_align_mismatch_pairs(align)
        else:
            mis_align_pair_list = get_No_MD_align_mismatch_pairs(align, ref_dict)
#         print(mis_align_pair_list)
        # 0region_index, 1reads_id, 2align_strand, 3extend_length,4CT_count, 5Ct_max_gap, 6GA_count, 7GA_max_gap
        
        # 如果这个reads至少存在一个mutation信息    
        if mis_align_pair_list:
            # checked
            align_strand = "-" if align.is_reverse else "+"
            aligned_reads_id = index + 1
            extend_length = num_extend
            
            # 如果只存在一个mutation，不做判断，直接存入list
            if len(mis_align_pair_list)==1:
                ls_line = []
                if mis_align_pair_list[0][2]=='C' and mis_align_pair_list[0][3]=='T':
                    ls_line = [region_index, aligned_reads_id, align_strand, extend_length, 1, 0, 0, 0]
                elif mis_align_pair_list[0][2]=='G' and mis_align_pair_list[0][3]=='A':
                    ls_line = [region_index, aligned_reads_id, align_strand, extend_length, 0, 0, 1, 0]

            # 如果存在两个或两个以上的mutation        
            else:
                ls_line1 = []
                ls_line2 = []
                # 先把CT的全筛出来
                ls_this_reads_info = [site for site in mis_align_pair_list if site[2]=='C' and site[3]=='T']
                # 如果筛不到，没有就没有
                # 如果筛到至少一个
                if ls_this_reads_info:
                    # 如果有一个就加到ls_table中
                    if len(ls_this_reads_info)==1:
                        ls_line = [region_index, aligned_reads_id, align_strand, extend_length, 1, 0, 0, 0]
                    # 如果有更多再计算count和gap
                    else:# todo 
                        ls_first = ls_this_reads_info[0]
                        ls_last = ls_this_reads_info[-1]
#                         print(ls_first[1])# todo!
                        ls_line1 = [region_index, aligned_reads_id, align_strand, extend_length, len(ls_this_reads_info),ls_last[0]-ls_first[0],0,0]
                # 再把GA的全筛出来
                ls_this_reads_info = [site for site in mis_align_pair_list if site[2]=='G' and site[3]=='A']
                # 如果筛不到，没有就没有
                # 如果筛到至少一个
                if ls_this_reads_info:
                    # 如果有一个就加到ls_table中
                    if len(ls_this_reads_info)==1:
                        ls_line = [region_index, aligned_reads_id, align_strand, extend_length, 0, 0, 1, 0]
                    # 如果有更多再计算count和gap
                    else:# todo 
                        ls_first = ls_this_reads_info[0]
                        ls_last = ls_this_reads_info[-1]
#                         print(ls_first[1])# todo!
                        ls_line2 = [region_index, aligned_reads_id, align_strand, extend_length,0,0,len(ls_this_reads_info),ls_last[0]-ls_first[0]]
                if ls_line1 and ls_line2:
                    ls_line = [region_index, aligned_reads_id, align_strand, extend_length,ls_line1[4]+ls_line2[4], ls_line1[5]+ls_line2[5],ls_line1[6]+ls_line2[6], ls_line1[7]+ls_line2[7]]
                elif ls_line1:
                    ls_line = ls_line1
                elif ls_line2:
                    ls_line = ls_line2
                else:
                    pass
                if ls_line:
                    ls_table.append(ls_line)
                    
                # 既没有CT也没有GA的直接pass
            
                

            
            
            
        if index > 1000:
            break
# ls_table = [i for i in ls_table if i[4]!=0 and i[6]!=0]
# ls_table
# Out:
# [['VEGFA-Site2-pRBS-1', 103, '-', 100, 2, 11, 3, 9],
#  ['VEGFA-Site2-pRBS-4', 218, '+', 100, 2, 6, 8, 12],
#  ['VEGFA-Site2-pRBS-4', 256, '+', 100, 2, 6, 7, 12],
#  ['VEGFA-Site2-pRBS-4', 396, '-', 100, 2, 6, 7, 12],
#  ['VEGFA-Site2-pRBS-9', 295, '+', 100, 3, 8, 2, 2],
#  ['VEGFA-Site2-pRBS-11', 505, '+', 100, 2, 1, 5, 8],
#  ['VEGFA-Site2-pRBS-11', 507, '+', 100, 2, 1, 3, 4],
#  ['VEGFA-Site2-pRBS-11', 572, '+', 100, 2, 1, 16, 69],
#  ['VEGFA-Site2-pRBS-11', 633, '+', 100, 2, 1, 8, 17],
#  ['VEGFA-Site2-pRBS-11', 648, '-', 100, 2, 1, 16, 69],
#  ['VEGFA-Site2-pRBS-11', 723, '-', 100, 2, 1, 8, 17],
#  ['VEGFA-Site2-pRBS-14', 125, '+', 100, 4, 4, 2, 32],
#  ['VEGFA-Site2-pRBS-20', 98, '-', 100, 2, 2, 9, 30],
#  ['VEGFA-Site2-pRBS-20', 151, '-', 100, 3, 11, 5, 12],
#  ['VEGFA-Site2-pRBS-20', 171, '-', 100, 2, 1, 7, 9],
#  ['VEGFA-Site2-pRBS-20', 226, '-', 100, 2, 9, 7, 46],
#  ['VEGFA-Site2-pRBS-31', 169, '+', 100, 2, 8, 7, 7],
#  ['VEGFA-Site2-pRBS-31', 203, '-', 100, 2, 8, 7, 7],
#  ['VEGFA-Site2-pRBS-37', 511, '-', 100, 3, 2, 2, 7],
#  ['VEGFA-Site2-pRBS-38', 125, '-', 100, 2, 13, 7, 7],
#  ['VEGFA-Site2-pRBS-42', 183, '+', 100, 2, 131, 6, 13],
#  ['VEGFA-Site2-pRBS-46', 186, '-', 100, 2, 111, 9, 16],
#  ['VEGFA-Site2-pRBS-53', 235, '+', 100, 5, 5, 2, 3],
#  ['VEGFA-Site2-pRBS-53', 495, '+', 100, 8, 10, 2, 3],
#  ['VEGFA-Site2-pRBS-53', 714, '+', 100, 5, 5, 3, 8],
#  ['VEGFA-Site2-pRBS-53', 724, '-', 100, 5, 15, 2, 22],
#  ['VEGFA-Site2-pRBS-55', 48, '+', 100, 2, 1, 2, 10],
#  ['VEGFA-Site2-pRBS-55', 91, '-', 100, 3, 6, 3, 31],
#  ['VEGFA-Site2-pRBS-56', 516, '-', 100, 2, 3, 4, 4],
#  ['VEGFA-Site2-pRBS-56', 892, '-', 100, 2, 6, 5, 101],
#  ['VEGFA-Site2-pRBS-56', 894, '-', 100, 3, 6, 5, 101],
#  ['VEGFA-Site2-pRBS-75', 51, '+', 100, 2, 58, 6, 8],
#  ['VEGFA-Site2-pRBS-76', 80, '+', 100, 8, 11, 6, 9],
#  ['VEGFA-Site2-pRBS-79', 141, '+', 100, 3, 4, 5, 4],
#  ['VEGFA-Site2-pRBS-83', 83, '+', 100, 2, 7, 4, 20],
#  ['VEGFA-Site2-pRBS-85', 239, '-', 100, 2, 58, 2, 45],
#  ['VEGFA-Site2-pRBS-87', 67, '+', 100, 7, 108, 5, 79],
#  ['VEGFA-Site2-pRBS-93', 271, '+', 100, 2, 1, 3, 46],
#  ['VEGFA-Site2-pRBS-93', 345, '-', 100, 6, 5, 5, 30],
#  ['VEGFA-Site2-pRBS-97', 252, '-', 100, 5, 8, 9, 12],
#  ['VEGFA-Site2-pRBS-97', 334, '+', 100, 5, 8, 10, 23],
#  ['VEGFA-Site2-pRBS-100', 286, '-', 100, 7, 9, 2, 10],
#  ['VEGFA-Site2-pRBS-100', 289, '-', 100, 4, 3, 2, 10],
#  ['VEGFA-Site2-pRBS-100', 366, '+', 100, 7, 8, 3, 17],
#  ['VEGFA-Site2-pRBS-100', 535, '+', 100, 6, 5, 4, 17],
#  ['VEGFA-Site2-pRBS-102', 109, '-', 100, 9, 12, 2, 22],
#  ['VEGFA-Site2-pRBS-102', 110, '-', 100, 6, 6, 2, 8],
#  ['VEGFA-Site2-pRBS-108', 53, '-', 100, 5, 4, 2, 51],
#  ['VEGFA-Site2-pRBS-112', 118, '+', 100, 2, 1, 3, 3],
#  ['VEGFA-Site2-pRBS-119', 111, '+', 100, 8, 10, 2, 10],
#  ['VEGFA-Site2-pRBS-119', 121, '+', 100, 7, 8, 2, 53],
#  ['VEGFA-Site2-pRBS-120', 815, '-', 100, 2, 3, 6, 5],
#  ['VEGFA-Site2-pRBS-124', 169, '-', 100, 2, 18, 6, 5],
#  ['VEGFA-Site2-pRBS-124', 248, '+', 100, 3, 8, 2, 1],
#  ['VEGFA-Site2-pRBS-124', 381, '+', 100, 2, 2, 2, 11],
#  ['VEGFA-Site2-pRBS-126', 5, '-', 100, 2, 40, 2, 11],
#  ['VEGFA-Site2-pRBS-132', 368, '-', 100, 2, 1, 2, 4],
#  ['VEGFA-Site2-pRBS-132', 422, '-', 100, 8, 10, 2, 11],
#  ['VEGFA-Site2-pRBS-134', 726, '+', 100, 3, 13, 3, 2],
#  ['VEGFA-Site2-pRBS-136', 357, '+', 100, 2, 120, 6, 10],
#  ['VEGFA-Site2-pRBS-136', 488, '-', 100, 2, 93, 5, 8],
#  ['VEGFA-Site2-pRBS-138', 179, '-', 100, 2, 3, 2, 1],
#  ['VEGFA-Site2-pRBS-138', 705, '+', 100, 2, 10, 3, 5],
#  ['VEGFA-Site2-pRBS-138', 845, '-', 100, 2, 10, 3, 5],
#  ['VEGFA-Site2-pRBS-140', 371, '+', 100, 3, 5, 6, 6],
#  ['VEGFA-Site2-pRBS-143', 104, '+', 100, 2, 2, 4, 40],
#  ['VEGFA-Site2-pRBS-143', 111, '+', 100, 2, 2, 4, 32],
#  ['VEGFA-Site2-pRBS-143', 116, '-', 100, 2, 2, 4, 32],
#  ['VEGFA-Site2-pRBS-144', 124, '+', 100, 4, 8, 7, 9],
#  ['VEGFA-Site2-pRBS-145', 28, '+', 100, 2, 24, 8, 13],
#  ['VEGFA-Site2-pRBS-148', 3, '+', 100, 4, 4, 3, 9],
#  ['VEGFA-Site2-pRBS-148', 13, '-', 100, 4, 4, 3, 9],
#  ['VEGFA-Site2-pRBS-149', 178, '-', 100, 2, 1, 4, 19],
#  ['VEGFA-Site2-pRBS-149', 260, '-', 100, 3, 2, 3, 10],
#  ['VEGFA-Site2-pRBS-151', 18, '+', 100, 16, 72, 2, 52],
#  ['VEGFA-Site2-pRBS-151', 31, '-', 100, 14, 47, 2, 52],
#  ['VEGFA-Site2-pRBS-168', 225, '+', 100, 5, 6, 2, 4],
#  ['VEGFA-Site2-pRBS-173', 29, '-', 100, 2, 2, 2, 29],
#  ['VEGFA-Site2-pRBS-177', 75, '+', 100, 2, 49, 6, 10],
#  ['VEGFA-Site2-pRBS-187', 62, '-', 100, 2, 6, 4, 3],
#  ['VEGFA-Site2-pRBS-187', 94, '-', 100, 2, 1, 5, 6],
#  ['VEGFA-Site2-pRBS-187', 130, '+', 100, 2, 7, 3, 126],
#  ['VEGFA-Site2-pRBS-188', 41, '+', 100, 4, 8, 3, 2],
#  ['VEGFA-Site2-pRBS-190', 322, '-', 100, 4, 3, 2, 59],
#  ['VEGFA-Site2-pRBS-190', 700, '+', 100, 2, 89, 2, 73],
#  ['VEGFA-Site2-pRBS-193', 129, '+', 100, 7, 8, 2, 2],
#  ['VEGFA-Site2-pRBS-196', 156, '-', 100, 2, 40, 3, 3],
#  ['VEGFA-Site2-pRBS-207', 95, '+', 100, 5, 7, 3, 11],
#  ['VEGFA-Site2-pRBS-208', 110, '-', 100, 4, 44, 4, 5],
#  ['VEGFA-Site2-pRBS-209', 318, '-', 100, 2, 1, 3, 8],
#  ['VEGFA-Site2-pRBS-211', 106, '-', 100, 9, 14, 2, 1],
#  ['VEGFA-Site2-pRBS-211', 109, '+', 100, 8, 27, 2, 1],
#  ['VEGFA-Site2-pRBS-224', 282, '-', 100, 3, 17, 2, 27],
#  ['VEGFA-Site2-pRBS-236', 92, '+', 100, 7, 11, 2, 7],
#  ['VEGFA-Site2-pRBS-236', 136, '-', 100, 5, 6, 2, 6],
#  ['VEGFA-Site2-pRBS-236', 137, '-', 100, 5, 15, 3, 97],
#  ['VEGFA-Site2-pRBS-236', 159, '+', 100, 7, 10, 2, 70],
#  ['VEGFA-Site2-pRBS-240', 130, '+', 100, 2, 96, 5, 66],
#  ['VEGFA-Site2-pRBS-246', 288, '-', 100, 6, 5, 3, 9],
#  ['VEGFA-Site2-pRBS-246', 385, '+', 100, 6, 5, 4, 13],
#  ['VEGFA-Site2-pRBS-246', 497, '+', 100, 6, 5, 2, 9],
#  ['VEGFA-Site2-pRBS-246', 562, '+', 100, 7, 8, 2, 4],
#  ['VEGFA-Site2-pRBS-246', 564, '-', 100, 7, 8, 2, 4],
#  ['VEGFA-Site2-pRBS-246', 638, '+', 100, 5, 4, 2, 4],
#  ['VEGFA-Site2-pRBS-253', 273, '-', 100, 2, 1, 6, 6],
#  ['VEGFA-Site2-pRBS-264', 45, '+', 100, 2, 31, 2, 134],
#  ['VEGFA-Site2-pRBS-272', 101, '+', 100, 7, 10, 2, 10],
#  ['VEGFA-Site2-pRBS-281', 65, '+', 100, 3, 10, 2, 40],
#  ['VEGFA-Site2-pRBS-305', 74, '+', 100, 2, 8, 2, 2],
#  ['VEGFA-Site2-pRBS-308', 244, '+', 100, 2, 10, 6, 15],
#  ['VEGFA-Site2-pRBS-324', 37, '+', 100, 4, 119, 9, 18],
#  ['VEGFA-Site2-pRBS-334', 83, '-', 100, 2, 20, 2, 2],
#  ['VEGFA-Site2-pRBS-344', 48, '+', 100, 3, 9, 3, 3],
#  ['VEGFA-Site2-pRBS-344', 76, '-', 100, 3, 7, 2, 3]]
